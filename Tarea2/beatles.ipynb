# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
path = 'nombres.csv'
col_names = ['anio','nombre','sexo','n','proporcion']
nombre_estudiado = 'John'
sexo_persona = 'M'

# %%
file = pd.read_csv('nombres.csv',encoding='latin-1',on_bad_lines='skip') #con el comando on_bad_lines skip, 
#de 858782 entradas quedaron 858778

# %%
pablos = file[(file['nombre']==nombre_estudiado) & (file['sexo']==sexo_persona)]

x = pablos['anio']
y = pablos['proporcion']

plt.plot(x,y,'r')
plt.xlabel('año')
plt.ylabel('proporcion')
plt.title(f"{nombre_estudiado}'s nacidos por año")
plt.show()

# %%
pablos[(pablos['n']==pablos['n'].max())]
# Out:
#         anio nombre sexo    n  proporcion
# 492277  1991   John    M  395     0.00131

# %%
pablos[(pablos['anio']==1970)]
# Out:
#         anio nombre sexo    n  proporcion
# 296303  1970   John    M  231     0.00081

# %%
pablos.iloc[40:,:]
# Out:
#         anio nombre sexo    n  proporcion
# 223445  1961   John    M   50    0.000185
# 231200  1962   John    M   53    0.000188
# 238987  1963   John    M   75    0.000263
# 246925  1964   John    M  246    0.000846
# 255038  1965   John    M  268    0.000839
# ...      ...    ...  ...  ...         ...
# 794493  2017   John    M   68    0.000310
# 808348  2018   John    M   92    0.000413
# 823828  2019   John    M   78    0.000369
# 838357  2020   John    M   56    0.000287
# 852115  2021   John    M   44    0.000247
#
# [61 rows x 5 columns]

# %%
pablos.iloc[:40,:]
# Out:
#         anio nombre sexo   n  proporcion
# 3822    1921   John    M   2    0.000043
# 7022    1922   John    M   2    0.000041
# 10313   1923   John    M   2    0.000039
# 13684   1924   John    M   3    0.000054
# 17231   1925   John    M   6    0.000104
# 20872   1926   John    M   3    0.000049
# 24674   1927   John    M   7    0.000099
# 28893   1928   John    M   1    0.000011
# 33387   1929   John    M   6    0.000066
# 38012   1930   John    M   1    0.000011
# 42522   1931   John    M   1    0.000012
# 46956   1932   John    M   9    0.000110
# 51409   1933   John    M   4    0.000049
# 55996   1934   John    M  11    0.000131
# 60749   1935   John    M   5    0.000057
# 65516   1936   John    M   5    0.000055
# 70475   1937   John    M   6    0.000062
# 75511   1938   John    M   8    0.000080
# 80711   1939   John    M   9    0.000078
# 86301   1940   John    M   6    0.000047
# 92000   1941   John    M   9    0.000067
# 97811   1942   John    M   8    0.000055
# 103558  1943   John    M  13    0.000087
# 109456  1944   John    M  13    0.000085
# 115263  1945   John    M  11    0.000069
# 121118  1946   John    M  13    0.000081
# 127189  1947   John    M  13    0.000075
# 133294  1948   John    M  17    0.000096
# 139399  1949   John    M  18    0.000101
# 145521  1950   John    M  16    0.000091
# 151617  1951   John    M  16    0.000089
# 157778  1952   John    M  22    0.000116
# 164472  1953   John    M  20    0.000089
# 171478  1954   John    M  28    0.000119
# 178708  1955   John    M  20    0.000079
# 186097  1956   John    M  15    0.000059
# 193431  1957   John    M  27    0.000107
# 200793  1958   John    M  22    0.000087
# 208367  1959   John    M  28    0.000107
# 215849  1960   John    M  32    0.000121
